# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
ppp_dataset = pd.read_csv('PPP_Loans_to_Connecticut_Businesses.csv', dtype = object)

# %%
ppp_dataset.head()
# Out:
#          LoanRange LoanAmount                    BusinessName  \
# 0  a $5-10 million        NaN                   AFFINECO, LLC
# 1  a $5-10 million        NaN  ALLIED PRINTING SERVICES, INC.
# 2  a $5-10 million        NaN      AMERICAN CUSTOMER CARE INC
# 3  a $5-10 million        NaN              APPLE CENTRAL, LLC
# 4  a $5-10 million        NaN              BL COMPANIES, INC.
#
#                 Address        City State   Zip NAICSCode  \
# 0           855 MAIN ST  BRIDGEPORT    CT  6604    561720
# 1          1 ALLIED WAY  MANCHESTER    CT  6042    323111
# 2     225 N Main Street     BRISTOL    CT  6010    561422
# 3      170 Mason Street   GREENWICH    CT  6830    722511
# 4  355 Research Parkway     Meriden    CT  6450    541330
#
#                       BusinessType RaceEthnicity      Gender      Veteran  \
# 0  Limited  Liability Company(LLC)    Unanswered  Unanswered   Unanswered
# 1         Subchapter S Corporation    Unanswered  Unanswered   Unanswered
# ...
